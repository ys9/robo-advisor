# %%
import yfinance as yf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime
import scipy.optimize as sco

# %%
pd.set_option('display.max_rows', 10)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

# %%
from main import get_financial_data, get_risk_profile, get_asset_allocation, \
    optimize_portfolio

# %%
etf_tickers = ['SPY', 'AGG', 'GLD', 'IJR', 'EFA']

# %%
end = datetime.now()
start = datetime(end.year - 5, end.month, end.day)

start_str = start.strftime('%Y-%m-%d')
end_str = end.strftime('%Y-%m-%d')

# %%
etf_data = get_financial_data(etf_tickers, start_str, end_str)
# Out:
# [*********************100%***********************]  5 of 5 completed
# Successfully fetched the following data:
# Ticker             AGG        EFA         GLD        IJR         SPY
# Date
# 2020-06-08  102.371185  55.979774  159.720001  69.874504  300.504669
# 2020-06-09  102.502373  55.252434  161.259995  68.172707  298.263885
# 2020-06-10  102.922279  55.131199  163.570007  65.694038  296.599609
# 2020-06-11  102.747337  52.178516  162.389999  60.329765  279.500916
# 2020-06-12  102.852280  53.079044  162.619995  61.855812  282.848114

# %%
etf_data.head()
# Out:
# Ticker             AGG        EFA         GLD        IJR         SPY
# Date
# 2020-06-08  102.371185  55.979774  159.720001  69.874504  300.504669
# 2020-06-09  102.502373  55.252434  161.259995  68.172707  298.263885
# 2020-06-10  102.922279  55.131199  163.570007  65.694038  296.599609
# 2020-06-11  102.747337  52.178516  162.389999  60.329765  279.500916
# 2020-06-12  102.852280  53.079044  162.619995  61.855812  282.848114

# %%
etf_data.columns
# Out:
# Index(['AGG', 'EFA', 'GLD', 'IJR', 'SPY'], dtype='object', name='Ticker')

# %%
etf_data.plot()
# Out:
# <Axes: xlabel='Date'>
